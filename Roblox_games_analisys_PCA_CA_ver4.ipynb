# %%
import kagglehub
import pandas as pd  # nao vai usar :(
import numpy as np
from scipy.spatial.distance import cdist
import pyspark.pandas as ps
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, coalesce, lower, regexp_replace, trim, when, length, upper, log1p, udf, percentile_approx
from pyspark.sql.types import DoubleType
from pyspark.ml.feature import VectorAssembler, StandardScaler, PCA
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import plotly.express as px

# %%
spark = SparkSession.builder.appName("roblox_games_data_analisys").getOrCreate()

# %%
spark.conf.set("spark.sql.ansi.enabled", False)

# %% [markdown]
# # Leitura dataset

# %% [markdown]
# ## Carregar datasets

# %%
'''
roblox-games-data - 1/22/2022 to 5/2/2022 *outdated???

info: Date,Active Users,Favorites,Total Visits,Date Created,Last Updated,Server Size,Genre,Title

# Download latest version
roblox_games_data_path = kagglehub.dataset_download("databitio/roblox-games-data")

print("Path to dataset files:", roblox_games_data_path)
'''
# Out:
# '\nroblox-games-data - 1/22/2022 to 5/2/2022 *outdated???\n\ninfo: Date,Active Users,Favorites,Total Visits,Date Created,Last Updated,Server Size,Genre,Title\n\n# Download latest version\nroblox_games_data_path = kagglehub.dataset_download("databitio/roblox-games-data")\n\nprint("Path to dataset files:", roblox_games_data_path)\n'

# %%
'''
roblox-games-dataset -  27/10/2024  *newest

info: Rank,Name,Active,Visits,Favorites,Likes,Deslikes,Rating
'''

# Download latest version
roblox_games_path = kagglehub.dataset_download("biggiefats/roblox-games-dataset")

print("Path to dataset files:", roblox_games_path)
# Out:
# Using Colab cache for faster access to the 'roblox-games-dataset' dataset.
# Path to dataset files: /kaggle/input/roblox-games-dataset

# %%
'''
roblox-dataset -  11/5/2024

info: Title,Creator,AgeRecomendation,ActivePlayers,Favorites,Visits,VoiceChat,
      Camera,Created,Updated,ServerSize,Genre,Likes,Dislikes,GameLink,Datafetch
'''

# Download latest version
roblox_dataset_path = kagglehub.dataset_download("jansenccruz/roblox-dataset")

print("Path to dataset files:", roblox_dataset_path)
# Out:
# Using Colab cache for faster access to the 'roblox-dataset' dataset.
# Path to dataset files: /kaggle/input/roblox-dataset

# %%
#Load dataframes

path=roblox_dataset_path+"/roblox_games_data.csv"
print(path)
df_old = spark.read.csv(path, header=True, inferSchema=True)
# Out:
# /kaggle/input/roblox-dataset/roblox_games_data.csv

# %%
df_old=df_old.withColumnRenamed("Favorites","Favourites")

# %%
df_old.show()
# Out:
# +--------------------+--------------------+-----------------+------+----------+-------+-------------+-------------+----------+----------+----------+---------------+-----+--------+--------------------+---------------+
# |               Title|             Creator|AgeRecommendation|Active|Favourites| Visits|    VoiceChat|       Camera|   Created|   Updated|ServerSize|          Genre|Likes|Dislikes|            GameLink|    DateFetched|
# +--------------------+--------------------+-----------------+------+----------+-------+-------------+-------------+----------+----------+----------+---------------+-----+--------+--------------------+---------------+
# |Catalog Avatar Cr...|         @ItsMuneeeb|         All Ages| 19469|   3438844|  2.8B+|    Supported|    Supported|  7/4/2021| 11/5/2024|        24|       Shopping|  1M+|   124K+|https://www.roblo...|11/5/2024 20:24|
# | [HALLOWEEN 🎃] T...|            CTStudio|         Ages 13+|  2709|   2911356|988.3M+|    Supported|Not Supported| 1/15/2021| 11/5/2024|        45|       Survival|982K+|   107K+|https://www.roblo...|11/5/2024 20:25|
# |[RANKED + MORE] F...|johnny cage fan g...|         All Ages|   148|     21024|  1.5M+|    Supported|Not Supported|10/26/2023| 11/5/2024|         8|            N/A| 5265|    1011|https://www.roblo...|11/5/2024 20:25|
# |PIGGY: MiniToon E...|         @TaintedMod|         All Ages|     0|         4|     44|Not Supported|Not Supported| 5/31/2024| 7/21/2024|         6|            N/A|    3|       0|https://www.roblo...|11/5/2024 20:25|
# |   Sol's RNG [Era 9]|        sol's studio|         All Ages| 22155|    635262|765.9M+|    Supported|Not Supported| 12/3/2023| 11/4/2024|        20|     Simulation|746K+|   101K+|https://www.roblo...|11/5/2024 20:25|
# |(V 1.0!) Sonic.EX...|@SonicThe_BlueBlurrr|         All Ages|     0|        33|   2799|Not Supported|    Supported|  9/8/2024|10/30/2024|        50|            N/A|   22|       1|https://www.roblo...|11/5/2024 20:25|
# |🎃Basketball Lege...|      InfinitySports|         All Ages|  3445|    358703|355.7M+|    Supported|Not Supported| 7/31/2023| 11/5/2024|        10|Sports & Racing|241K+|    52K+|https://www.roblo...|11/5/2024 20:25|
# |[⏰UPDATE] Slap Ba...|        Slap Battles|          Ages 9+|  9035|   2363252|  2.4B+|    Supported|    Supported| 2/17/2021| 11/2/2024|        16|         Action|  1M+|   245K+|https://www.roblo...|11/5/2024 20:25|
# |Nah I'd Win Battl...|     @ThanhAnh2022AA|         All Ages|    21|       238|129.4K+|Not Supported|    Supported| 4/29/2024| 11/4/2024|        10|            N/A|   48|      37|https://www.roblo...|11/5/2024 20:25|
# |[🗼UPD] Get Big S...|              Goofin|         All Ages|    74|     33655|  9.1M+|Not Supported|Not Supported| 3/20/2024| 11/3/2024|        10|     Simulation|100K+|    2975|https://www.roblo...|11/5/2024 20:25|
# |Vehicle Legends ?...|          QuadraTech|         All Ages|  5984|   2277362|  1.5B+|    Supported|Not Supported|  1/2/2020| 11/4/2024|        18|     Simulation|  1M+|    70K+|https://www.roblo...|11/5/2024 20:25|
# | [🥁] Tongue Battles|        LDS Fighting|         All Ages|  2603|    217480|131.6M+|    Supported|Not Supported| 3/12/2024| 11/5/2024|        18|         Action|383K+|    28K+|https://www.roblo...|11/5/2024 20:25|
# |[🕷️HALLOWEEN🕸️]...|Universe Time Studio|         Ages 13+| 14899|   1312542|796.9M+|    Supported|Not Supported|  6/4/2020| 11/5/2024|         1|            RPG|796K+|   134K+|https://www.roblo...|11/5/2024 20:26|
# |Survive in the Ab...|@lauradevilhenabe...|         All Ages|     8|     50049|  2.1M+|    Supported|Not Supported| 7/18/2024| 11/1/2024|        20|       Survival| 1889|     718|https://www.roblo...|11/5/2024 20:26|
# |         Studio Lite|  @ScottSpiritWalker|         All Ages|   300|     53036| 15.7M+|Not Supported|Not Supported| 9/20/2022| 11/5/2024|         1|     Simulation| 16K+|    3902|https://www.roblo...|11/5/2024 20:26|
# |[🎃 EVENT] Drivin...|Driving Empire by...|         All Ages|  9627|  13733888|  1.6B+|    Supported|Not Supported| 6/23/2019| 11/5/2024|        25|     Simulation|  1M+|   113K+|https://www.roblo...|11/5/2024 20:26|
# |🎉 🏆 SUPER GUYS ...|           SGD GAMES|         All Ages|   125|     93929|  9.6M+|Not Supported|Not Supported|  4/6/2024| 11/3/2024|        12| Party & Casual| 1337|     770|https://www.roblo...|11/5/2024 20:26|
# |[🎃] Dungeon Ques...|Dungeon Quest by ...|          Ages 9+|  5234|   4243151|  2.1B+|Not Supported|Not Supported| 9/26/2018| 11/2/2024|        40|            RPG|  1M+|    96K+|https://www.roblo...|11/5/2024 20:26|
# |weird strict dad ...|    BlueLoop Studios|         All Ages|   515|    465052|341.1M+|    Supported|Not Supported| 9/16/2023| 9/21/2024|        20|      Adventure|115K+|    21K+|https://www.roblo...|11/5/2024 20:26|
# |     MeepCity (2017)|  @danodanya12Beta21|         All Ages|     0|         2|     68|    Supported|    Supported|10/27/2024|10/31/2024|        50|            N/A|    1|       0|https://www.roblo...|11/5/2024 20:26|
# +--------------------+--------------------+-----------------+------+----------+-------+-------------+-------------+----------+----------+----------+---------------+-----+--------+--------------------+---------------+
# only showing top 20 rows

# %%
path=roblox_games_path+"/roblox_games.csv"
print(path)
df_new = spark.read.csv(path, header=True, inferSchema=True)
# Out:
# /kaggle/input/roblox-games-dataset/roblox_games.csv

# %%
df_new.show()
# Out:
# +----+--------------------+-------+--------------+----------+---------+---------+------+
# |Rank|                Name| Active|        Visits|Favourites|    Likes| Dislikes|Rating|
# +----+--------------------+-------+--------------+----------+---------+---------+------+
# |  #1|         Blox Fruits|483,372|41,346,317,182|13,574,097|8,521,670|  676,846| 92.64|
# |  #2|     Brookhaven 🏡RP|474,141|55,635,148,446|22,117,653|6,108,763|  955,845| 86.47|
# |  #3| Dress To Impress 💜|297,764| 3,876,511,994| 3,182,036|2,042,092|  188,403| 91.55|
# |  #4|    PETS GO! ✨ [NEW]|172,411|   145,691,211|   199,254|  275,267|   20,140| 93.18|
# |  #5|    Murder Mystery 2|159,531|18,310,453,247|19,306,585|8,001,198|  786,705| 91.05|
# |  #6|[UPDATE 1] Anime ...|142,586|   534,044,793|   578,491|1,592,383|   52,159| 96.83|
# |  #7|The Strongest Bat...|142,531| 8,747,773,201| 4,177,434|2,931,689|  565,313| 83.83|
# |  #8|Pet Simulator 99! 🎃|131,088| 1,527,851,114| 1,479,726|2,586,908|  106,245| 96.05|
# |  #9|          Adopt Me! |109,439|37,679,655,130|26,994,071|7,323,639|1,441,230| 83.56|
# | #10|  Berry Avenue 🏠 RP| 77,150| 4,495,186,748| 2,309,040|  681,793|   99,257| 87.29|
# | #11|        🎃 DOORS 👁️| 70,116| 5,714,365,246| 6,688,592|3,888,476|  289,280| 93.08|
# | #12|           🎃 RIVALS| 63,878| 1,247,731,942|13,213,395|2,751,053|  118,321| 95.88|
# | #13|[TEN SHADOWS] Juj...| 63,255|   966,867,976|   943,813|  747,236|  133,201| 84.87|
# | #14|   🦇Anime Defenders| 63,015| 3,031,330,440|   683,248|1,940,077|   59,410| 97.03|
# | #15|🎟️Dandy's World ...| 58,744|   419,230,503|   361,526|  211,995|   17,131| 92.52|
# | #16|(UPDATE 7) King L...| 48,482| 3,160,603,105| 2,277,534|1,338,140|  135,726| 90.79|
# | #17|          [🎃] Fisch| 44,174|    23,455,912|   149,970|   74,557|    9,433| 88.77|
# | #18|[⚔️PVP] Toilet To...| 42,748| 5,053,264,586| 1,116,753|1,143,631|  163,039| 87.52|
# | #19|Five Nights TD [E...| 38,875|   386,846,247|   235,250|  206,878|   15,767| 92.92|
# | #20|        ✨🎃Evade 🎃✨| 37,301| 5,225,026,775| 5,355,653|2,116,112|  130,103| 94.21|
# +----+--------------------+-------+--------------+----------+---------+---------+------+
# only showing top 20 rows

# %% [markdown]
# ## Remove Duplicate Rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, desc, col

# For df_old: remove duplicates based on 'Title', keeping the most recent 'DateFetched'
window_old = Window.partitionBy("Title").orderBy(desc("DateFetched"))
df_old = df_old.withColumn("row_num", row_number().over(window_old)).filter(col("row_num") == 1).drop("row_num")

# print("df_old after removing duplicates by Title and keeping most recent DateFetched:")
# df_old.show(5, truncate=False)

# %%
df_count = df_old.groupBy("Title").count().orderBy("count", ascending=False)
df_count.show()
# Out:
# +--------------------+-----+
# |               Title|count|
# +--------------------+-----+
# | Anime Catching S...|    1|
# |   Gun Armory Tycoon|    1|
# | PETS GO! 🍀 [ +1...|    1|
# | PETS GO! 🍀 [+1B...|    1|
# | Piggy [DECAY CHA...|    1|
# | Roblox Spirit Ha...|    1|
# | SCP Containment ...|    1|
# |    Sol's RNG [Eon1]|    1|
# |   Sol's RNG [Era 9]|    1|
# | Sonic Evocative:...|    1|
# | Sonic.EXE: The D...|    1|
# | Sonic.EXE: The d...|    1|
# |        Strict Mom👿|    1|
# | [ BUMBAA  + 16 ]...|    1|
# | [ DIVA + 15] TOD 🎃|    1|
# | [ 😇 ]GnomeCode'...|    1|
# | [Fixed] Sonic Ev...|    1|
# | [HALLOWEEN 🎃] T...|    1|
# | [Modded TITANIC]...|    1|
# | [RETURN] Z O th ...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %%
# For df_new: remove duplicates based on 'Name', keeping the one with the most 'Visits'
window_new = Window.partitionBy("Name").orderBy(desc("Visits"))
df_new = df_new.withColumn("row_num", row_number().over(window_new)).filter(col("row_num") == 1).drop("row_num")

# print("\ndf_new after removing duplicates by Name and keeping most Visits:")
# df_new.show(5, truncate=False)

# %%
df_count = df_new.groupBy("Name").count().orderBy("count", ascending=False)
df_count.show()
# Out:
# +--------------------+-----+
# |                Name|count|
# +--------------------+-----+
# |   Gun Armory Tycoon|    1|
# | Michael's Zombie...|    1|
# | Piggy [DECAY CHA...|    1|
# |   Sol's RNG [Era 9]|    1|
# | Sonic.EXE: The d...|    1|
# | [ 🎃 HALLOWEEN ]...|    1|
# | [HALLOWEEN 🎃] T...|    1|
# |     🔥 Dragon Blox |    1|
# |        🚁 My Prison|    1|
# |(HALLOWEEN EVENT,...|    1|
# |(HALLOWEEN) Inter...|    1|
# |(UPDATE 7) King L...|    1|
# |(🎃Halloween🎃) L...|    1|
# |(📱 PHONES, MINIM...|    1|
# |(🔪UPDATE🔪) Tha ...|    1|
# |+1 Blocks Every S...|    1|
# |+1 Fat Every Seco...|    1|
# |         1% Win Obby|    1|
# |2 Player Sushi Ty...|    1|
# |3-2-1 Blast Off S...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## Normalização dos nomes

# %%
EVENT_REGEX = (
    r"(?i)\b("
    r"new\s+update|big\s+update|mega\s+update|huge\s+update|balance\s+update|bug\s+fixes?|"
    r"update|upd|release|revamp|rework|patch|"
    r"halloween|christmas|xmas|winter|summer|spring|easter|valentine'?s?|thanksgiving|"
    r"black\s+friday|april\s+fools?|new\s+year|lunar\s+new\s+year|"
    r"free\s+ugc|ugc|limited\s+time|limited|new\s+codes?|codes?|code|rewards?|giveaway|"
    r"live\s+event|event|"
    r"new\s+map|new\s+world|new\s+area|new\s+island|new\s+pets?|new\s+eggs?|new\s+boss|"
    r"new\s+raid|new\s+weapons?|new\s+skins?|new\s+units?|new\s+fruit|new\s+quest|new\s+mode|"
    r"beta|alpha|demo|testing|early\s+access|open\s+beta|closed\s+beta"
    r")\b"
)

normalized_column_name="Normalized_name"

def criar_nome_normalizado(df, coluna_nome="Name"):
    return (
        df
        .withColumn(normalized_column_name, lower(col(coluna_nome)))

        # Remove emojis e símbolos estranhos
        .withColumn(
            normalized_column_name,
            regexp_replace(col(normalized_column_name), r"[^\w\s\-\:\|\!\(\)\[\]&']", " ")
        )

        # Remove blocos como [UPDATE], (HALLOWEEN), [NEW CODES]
        .withColumn(
            normalized_column_name,
            regexp_replace(
                col(normalized_column_name),
                r"(?i)[\[\(]\s*[^)\]]*(update|upd|event|codes?|ugc|halloween|christmas|xmas|easter|winter|summer|beta|alpha)[^)\]]*[\]\)]",
                " "
            )
        )

        # Remove palavras de evento/update
        .withColumn(
            normalized_column_name,
            regexp_replace(col(normalized_column_name), EVENT_REGEX, " ")
        )

        # Padroniza e limpa separadores
        .withColumn(normalized_column_name, regexp_replace(col(normalized_column_name), r"&", " and "))
        .withColumn(normalized_column_name, regexp_replace(col(normalized_column_name), r"[\[\]\(\)\|:!\-]", " "))
        .withColumn(normalized_column_name, regexp_replace(col(normalized_column_name), r"\s+", " "))
        .withColumn(normalized_column_name, trim(col(normalized_column_name)))

        # Se o resultado ficar vazio, volta para o nome original em lowercase
        .withColumn(
            normalized_column_name,
            when(length(col(normalized_column_name)) > 0, col(normalized_column_name))
            .otherwise(lower(col(coluna_nome)))
        )
    )

# %%
df_old = criar_nome_normalizado(df_old,coluna_nome="Title")
#df_old.show()

# %%
df_new = criar_nome_normalizado(df_new,coluna_nome="Name")
#df_new.show()

# %% [markdown]
# ## Correção colunas numericas

# %%
def correct_number_columns(col_name, num_type="bigint"):
    """
    Converts numeric string columns like:
    12K+ -> 12000
    1.5M -> 1500000
    2B   -> 2000000000
    950+ -> 950
    300  -> 300
    Handles commas in numbers.
    """

    c = upper(trim(col(col_name)))

    # Remove '+' wherever it appears, as it's not part of the number we want to cast
    c = regexp_replace(c, r"\+", "")

    # Remove commas from numbers (e.g., "483,372" -> "483372")
    c = regexp_replace(c, r",", "")

    # Extract only the numeric part and cast to DoubleType to handle decimals
    number = regexp_replace(c, r"[KMB]", "").cast(DoubleType())

    result = (
        when(c.rlike(r"K$"), number * 1000)
        .when(c.rlike(r"M$"), number * 1000000)
        .when(c.rlike(r"B$"), number * 1000000000)
        .otherwise(number)
        .cast(num_type) # Final cast to the desired integer type
    )

    return result

# %% [markdown]
# ### Df_old

# %%
df_old = df_old.withColumn("Likes", correct_number_columns("Likes", "bigint"))
df_old = df_old.withColumn("Dislikes", correct_number_columns("Dislikes", "bigint"))
df_old = df_old.withColumn("Active", correct_number_columns("Active", "int"))
df_old = df_old.withColumn("Favourites", correct_number_columns("Favourites", "bigint"))
df_old = df_old.withColumn("Visits", correct_number_columns("Visits", "bigint"))

# %% [markdown]
# ### Df_new

# %%
df_new=df_new.drop("Rank")
df_new=df_new.drop("Rating")

# %%
df_new=df_new.withColumn("Active",correct_number_columns("Active","int"))
df_new=df_new.withColumn("Visits",correct_number_columns("Visits","bigint"))
df_new=df_new.withColumn("Favourites",correct_number_columns("Favourites","bigint"))
df_new=df_new.withColumn("Likes",correct_number_columns("Likes","bigint"))
df_new=df_new.withColumn("Dislikes",correct_number_columns("Dislikes","bigint"))

# %%
cols_update = ["Visits", "Likes", "Dislikes", "Favourites", "Active"]

# %%
df_new_update = df_new.select("Normalized_name",
        *[col(c).alias(f"{c}_new")
        for c in cols_update
        if c in df_new.columns]
)

# %% [markdown]
# ## Juntar dataframes

# %%
df_join = df_old.join(df_new_update, on="Normalized_name", how="left")

# %%
for c in cols_update:
    new_col = f"{c}_new"

    if c in df_join.columns and new_col in df_join.columns:
        df_join = df_join.withColumn(
            c,
            coalesce(col(new_col), col(c))
        )

# %%
df_final = df_join.drop(
    *[
        f"{c}_new"
        for c in cols_update
        if f"{c}_new" in df_join.columns
    ]
)

# %%
df_final.show()
# Out:
# +--------------------+--------------------+--------------------+-----------------+------+----------+-----------+-------------+-------------+----------+----------+----------+-------------+-------+--------+--------------------+----------------+
# |     Normalized_name|               Title|             Creator|AgeRecommendation|Active|Favourites|     Visits|    VoiceChat|       Camera|   Created|   Updated|ServerSize|        Genre|  Likes|Dislikes|            GameLink|     DateFetched|
# +--------------------+--------------------+--------------------+-----------------+------+----------+-----------+-------------+-------------+----------+----------+----------+-------------+-------+--------+--------------------+----------------+
# |anime catching si...| Anime Catching S...|           BestBunny|         All Ages|   206|    191886|   79300000|Not Supported|Not Supported| 1/13/2023| 8/15/2024|        12|   Simulation| 285000|   12000|https://www.roblo...| 11/9/2024 23:52|
# |   gun armory tycoon|   Gun Armory Tycoon|       Raven Network|          Ages 9+|  1006|     55544|   32066588|Not Supported|    Supported| 4/25/2024|10/17/2024|         8|   Simulation|  46677|    3736|https://www.roblo...| 11/6/2024 22:47|
# |     pets go 1b luck| PETS GO! 🍀 [ +1...|BK Games Uploading 3|         All Ages|  4281|      1521|     546300|    Supported|    Supported|10/28/2024| 11/6/2024|        10|          N/A|   1207|      94|https://www.roblo...| 11/6/2024 22:35|
# |     pets go 1b luck| PETS GO! 🍀 [+1B...|BK Games Uploading 3|         All Ages|  1939|       685|     227800|    Supported|    Supported|10/28/2024| 11/5/2024|        10|          N/A|    588|      42|https://www.roblo...| 11/5/2024 21:17|
# | piggy decay chapter| Piggy [DECAY CHA...|           @MiniToon|          Ages 9+| 27466|  11669525|13110395425|    Supported|Not Supported| 1/23/2020| 11/5/2024|         6|     Survival|3615821|  406011|https://www.roblo...| 11/6/2024 21:56|
# |  roblox spirit 2024| Roblox Spirit Ha...|         @JohnTRoblo|         All Ages|    13|       731|     417900|Not Supported|Not Supported| 4/20/2024| 9/18/2024|        50|Entertainment|    348|      98|https://www.roblo...| 11/9/2024 23:57|
# |scp containment b...| SCP Containment ...|         @joshman901|         All Ages|     6|     27872|   11600000|Not Supported|Not Supported| 5/12/2018|11/10/2022|         6|          N/A|   4409|    1207|https://www.roblo...| 11/5/2024 21:37|
# |      sol's rng eon1|    Sol's RNG [Eon1]|        sol's studio|         All Ages| 81975|    640825|  778100000|Not Supported|Not Supported| 12/3/2023|11/12/2024|        20|   Simulation| 755000|  101000|https://www.roblo...| 11/13/2024 9:15|
# |     sol's rng era 9|   Sol's RNG [Era 9]|        sol's studio|         All Ages| 24826|    633329|  760264927|Not Supported|Not Supported| 12/3/2023| 11/9/2024|        20|   Simulation| 742478|  100411|https://www.roblo...| 11/9/2024 23:45|
# |sonic evocative r...| Sonic Evocative:...|Tails Team Roblox...|         All Ages|    80|      1542|    3400000|Not Supported|Not Supported| 6/29/2024| 11/9/2024|        50|   Simulation|    244|     101|https://www.roblo...|11/11/2024 11:29|
# |sonic exe the dis...| Sonic.EXE: The D...|        @OutLaikRBLX|         Ages 13+|  7446|     69118|   40646073|Not Supported|Not Supported|  9/9/2023|11/11/2024|         8|     Survival|  33850|    4351|https://www.roblo...| 11/13/2024 9:38|
# |sonic exe the dis...| Sonic.EXE: The d...|        @OutLaikRBLX|         All Ages|  7446|     69118|   40646073|Not Supported|Not Supported|  9/9/2023| 11/2/2024|         8|     Survival|  33850|    4351|https://www.roblo...| 11/6/2024 22:47|
# |          strict mom|        Strict Mom👿|      Creepy Studio.|         All Ages|    87|     51231|    6500000|Not Supported|Not Supported|  1/3/2024|11/11/2024|        25|    Adventure|   4550|     770|https://www.roblo...| 11/13/2024 9:26|
# |       bumbaa 16 tod| [ BUMBAA  + 16 ]...|     OofMayy Studios|         All Ages|  6859|    232111|  153200000|Not Supported|Not Supported| 1/25/2023| 11/9/2024|        30|       Social|  74000|    6912|https://www.roblo...| 11/9/2024 23:46|
# |         diva 15 tod| [ DIVA + 15] TOD 🎃|     OofMayy Studios|         All Ages|  2373|    230494|  151700000|    Supported|    Supported| 1/25/2023| 11/4/2024|        30|       Social|  73000|    6868|https://www.roblo...| 11/5/2024 20:29|
# |gnomecode's tower...| [ 😇 ]GnomeCode'...|        @noob_YT2823|         All Ages|     0|         3|        722|Not Supported|    Supported|  8/3/2024| 9/10/2024|        25|          N/A|      6|       3|https://www.roblo...| 11/5/2024 21:13|
# |fixed sonic evoca...| [Fixed] Sonic Ev...|Tails Team Roblox...|         All Ages|    93|      1571|    3400000|Not Supported|Not Supported| 6/29/2024|11/12/2024|        50|   Simulation|    245|     104|https://www.roblo...| 11/13/2024 9:39|
# |           the mimic| [HALLOWEEN 🎃] T...|            CTStudio|         Ages 13+| 12843|   2901837|  982471025|Not Supported|Not Supported| 1/15/2021| 11/5/2024|        45|     Survival| 979569|  107362|https://www.roblo...| 11/9/2024 23:44|
# |modded titanic pe...| [Modded TITANIC]...|        @buildZgame5|         All Ages|    30|     10507|     206100|    Supported|    Supported| 9/23/2024| 11/6/2024|        10|          N/A|    109|      66|https://www.roblo...| 11/6/2024 22:24|
# |return z o th cen...| [RETURN] Z O th ...|     @Windowsfan2006|         All Ages|     1|       442|     421200|Not Supported|Not Supported|  3/1/2021| 9/18/2022|        50|          N/A|     92|      36|https://www.roblo...| 11/9/2024 23:48|
# +--------------------+--------------------+--------------------+-----------------+------+----------+-----------+-------------+-------------+----------+----------+----------+-------------+-------+--------+--------------------+----------------+
# only showing top 20 rows

# %%
#df_final.printSchema()

# %% [markdown]
# # Analise inicial

# %% [markdown]
# ## Ajustes (selecionar colunas numericas)

# %%
df=df_final

# %%
#df.printSchema()

# %%
numeric_types = ["int", "bigint", "double", "float", "decimal", "long", "short"]

numeric_columns = [
    col_name
    for col_name, dtype in df.dtypes
    if dtype in numeric_types or dtype.startswith("decimal")
]
numeric_columns.append("Title")
numeric_columns.append("Genre")

# %%
df_num=df.select(numeric_columns)

# %%
#df_num.show()

# %%
df_num=df_num.pandas_api()

# %%
#df_num.head()

# %% [markdown]
# ## Valores Nan/Null

# %%
cols=df_num.columns

# %%
for i in cols:
    print(i,df_num[i].isna().sum())
    print(i,df_num[i].isnull().sum())
    df_na=df_num[df_num[i]=="N/A"]
    print(f"{i} nan_string {df_na[i].count()}")
# Out:
# Active 0
# Active 0
# Active nan_string 0
# Favourites 0
# Favourites 0
# Favourites nan_string 0
# Visits 0
# Visits 0
# Visits nan_string 0
# ServerSize 0
# ServerSize 0
# ServerSize nan_string 0
# Likes 0
# Likes 0
# Likes nan_string 0
# Dislikes 0
# Dislikes 0
# Dislikes nan_string 0
# Title 0
# Title 0
# Title nan_string 0
# Genre 0
# Genre 0
# Genre nan_string 487

# %% [markdown]
# ## Analises

# %%
df_final.show()
# Out:
# +--------------------+--------------------+--------------------+-----------------+------+----------+-----------+-------------+-------------+----------+----------+----------+-------------+-------+--------+--------------------+----------------+
# |     Normalized_name|               Title|             Creator|AgeRecommendation|Active|Favourites|     Visits|    VoiceChat|       Camera|   Created|   Updated|ServerSize|        Genre|  Likes|Dislikes|            GameLink|     DateFetched|
# +--------------------+--------------------+--------------------+-----------------+------+----------+-----------+-------------+-------------+----------+----------+----------+-------------+-------+--------+--------------------+----------------+
# |anime catching si...| Anime Catching S...|           BestBunny|         All Ages|   206|    191886|   79300000|Not Supported|Not Supported| 1/13/2023| 8/15/2024|        12|   Simulation| 285000|   12000|https://www.roblo...| 11/9/2024 23:52|
# |   gun armory tycoon|   Gun Armory Tycoon|       Raven Network|          Ages 9+|  1006|     55544|   32066588|Not Supported|    Supported| 4/25/2024|10/17/2024|         8|   Simulation|  46677|    3736|https://www.roblo...| 11/6/2024 22:47|
# |     pets go 1b luck| PETS GO! 🍀 [ +1...|BK Games Uploading 3|         All Ages|  4281|      1521|     546300|    Supported|    Supported|10/28/2024| 11/6/2024|        10|          N/A|   1207|      94|https://www.roblo...| 11/6/2024 22:35|
# |     pets go 1b luck| PETS GO! 🍀 [+1B...|BK Games Uploading 3|         All Ages|  1939|       685|     227800|    Supported|    Supported|10/28/2024| 11/5/2024|        10|          N/A|    588|      42|https://www.roblo...| 11/5/2024 21:17|
# | piggy decay chapter| Piggy [DECAY CHA...|           @MiniToon|          Ages 9+| 27466|  11669525|13110395425|    Supported|Not Supported| 1/23/2020| 11/5/2024|         6|     Survival|3615821|  406011|https://www.roblo...| 11/6/2024 21:56|
# |  roblox spirit 2024| Roblox Spirit Ha...|         @JohnTRoblo|         All Ages|    13|       731|     417900|Not Supported|Not Supported| 4/20/2024| 9/18/2024|        50|Entertainment|    348|      98|https://www.roblo...| 11/9/2024 23:57|
# |scp containment b...| SCP Containment ...|         @joshman901|         All Ages|     6|     27872|   11600000|Not Supported|Not Supported| 5/12/2018|11/10/2022|         6|          N/A|   4409|    1207|https://www.roblo...| 11/5/2024 21:37|
# |      sol's rng eon1|    Sol's RNG [Eon1]|        sol's studio|         All Ages| 81975|    640825|  778100000|Not Supported|Not Supported| 12/3/2023|11/12/2024|        20|   Simulation| 755000|  101000|https://www.roblo...| 11/13/2024 9:15|
# |     sol's rng era 9|   Sol's RNG [Era 9]|        sol's studio|         All Ages| 24826|    633329|  760264927|Not Supported|Not Supported| 12/3/2023| 11/9/2024|        20|   Simulation| 742478|  100411|https://www.roblo...| 11/9/2024 23:45|
# |sonic evocative r...| Sonic Evocative:...|Tails Team Roblox...|         All Ages|    80|      1542|    3400000|Not Supported|Not Supported| 6/29/2024| 11/9/2024|        50|   Simulation|    244|     101|https://www.roblo...|11/11/2024 11:29|
# |sonic exe the dis...| Sonic.EXE: The D...|        @OutLaikRBLX|         Ages 13+|  7446|     69118|   40646073|Not Supported|Not Supported|  9/9/2023|11/11/2024|         8|     Survival|  33850|    4351|https://www.roblo...| 11/13/2024 9:38|
# |sonic exe the dis...| Sonic.EXE: The d...|        @OutLaikRBLX|         All Ages|  7446|     69118|   40646073|Not Supported|Not Supported|  9/9/2023| 11/2/2024|         8|     Survival|  33850|    4351|https://www.roblo...| 11/6/2024 22:47|
# |          strict mom|        Strict Mom👿|      Creepy Studio.|         All Ages|    87|     51231|    6500000|Not Supported|Not Supported|  1/3/2024|11/11/2024|        25|    Adventure|   4550|     770|https://www.roblo...| 11/13/2024 9:26|
# |       bumbaa 16 tod| [ BUMBAA  + 16 ]...|     OofMayy Studios|         All Ages|  6859|    232111|  153200000|Not Supported|Not Supported| 1/25/2023| 11/9/2024|        30|       Social|  74000|    6912|https://www.roblo...| 11/9/2024 23:46|
# |         diva 15 tod| [ DIVA + 15] TOD 🎃|     OofMayy Studios|         All Ages|  2373|    230494|  151700000|    Supported|    Supported| 1/25/2023| 11/4/2024|        30|       Social|  73000|    6868|https://www.roblo...| 11/5/2024 20:29|
# |gnomecode's tower...| [ 😇 ]GnomeCode'...|        @noob_YT2823|         All Ages|     0|         3|        722|Not Supported|    Supported|  8/3/2024| 9/10/2024|        25|          N/A|      6|       3|https://www.roblo...| 11/5/2024 21:13|
# |fixed sonic evoca...| [Fixed] Sonic Ev...|Tails Team Roblox...|         All Ages|    93|      1571|    3400000|Not Supported|Not Supported| 6/29/2024|11/12/2024|        50|   Simulation|    245|     104|https://www.roblo...| 11/13/2024 9:39|
# |           the mimic| [HALLOWEEN 🎃] T...|            CTStudio|         Ages 13+| 12843|   2901837|  982471025|Not Supported|Not Supported| 1/15/2021| 11/5/2024|        45|     Survival| 979569|  107362|https://www.roblo...| 11/9/2024 23:44|
# |modded titanic pe...| [Modded TITANIC]...|        @buildZgame5|         All Ages|    30|     10507|     206100|    Supported|    Supported| 9/23/2024| 11/6/2024|        10|          N/A|    109|      66|https://www.roblo...| 11/6/2024 22:24|
# |return z o th cen...| [RETURN] Z O th ...|     @Windowsfan2006|         All Ages|     1|       442|     421200|Not Supported|Not Supported|  3/1/2021| 9/18/2022|        50|          N/A|     92|      36|https://www.roblo...| 11/9/2024 23:48|
# +--------------------+--------------------+--------------------+-----------------+------+----------+-----------+-------------+-------------+----------+----------+----------+-------------+-------+--------+--------------------+----------------+
# only showing top 20 rows

# %%
df_final.printSchema()
# Out:
# root
#  |-- Normalized_name: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Creator: string (nullable = true)
#  |-- AgeRecommendation: string (nullable = true)
#  |-- Active: integer (nullable = true)
#  |-- Favourites: long (nullable = true)
#  |-- Visits: long (nullable = true)
#  |-- VoiceChat: string (nullable = true)
#  |-- Camera: string (nullable = true)
#  |-- Created: string (nullable = true)
#  |-- Updated: string (nullable = true)
#  |-- ServerSize: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Likes: long (nullable = true)
#  |-- Dislikes: long (nullable = true)
#  |-- GameLink: string (nullable = true)
#  |-- DateFetched: string (nullable = true)

# %%
num_cols=cols.drop("Title")
num_cols=num_cols.drop("Genre")

# %%
df_num.head()
# Out:
#    Active  Favourites       Visits  ServerSize    Likes  Dislikes                      Title       Genre
# 0     206      191886     79300000          12   285000     12000   Anime Catching Simulator  Simulation
# 1    1006       55544     32066588           8    46677      3736          Gun Armory Tycoon  Simulation
# 2    4281        1521       546300          10     1207        94     PETS GO! 🍀 [ +1B LUCK]         N/A
# 3    1939         685       227800          10      588        42      PETS GO! 🍀 [+1B LUCK]         N/A
# 4   27466    11669525  13110395425           6  3615821    406011      Piggy [DECAY CHAPTER]    Survival

# %%
df_num.describe()
# Out:
#               Active    Favourites        Visits   ServerSize         Likes      Dislikes
# count    1534.000000  1.534000e+03  1.534000e+03  1534.000000  1.534000e+03  1.534000e+03
# mean     4231.408735  9.806732e+05  4.501113e+08    25.663625  2.354806e+05  3.129972e+04
# std     22273.500075  2.630438e+06  2.414365e+09    29.441246  7.088276e+05  9.274837e+04
# min         0.000000  0.000000e+00  0.000000e+00     1.000000  0.000000e+00  0.000000e+00
# 25%        86.000000  7.506000e+03  1.400000e+06    10.000000  1.093000e+03  3.640000e+02
# 50%       804.000000  1.116010e+05  2.519544e+07    18.000000  2.300000e+04  3.757000e+03
# 75%      1924.000000  7.315230e+05  1.847692e+08    32.000000  1.400000e+05  2.153600e+04
# max    483372.000000  2.873764e+07  5.563515e+10   700.000000  8.521670e+06  1.441230e+06

# %% [markdown]
# ### Distribuições

# %%
for i in num_cols:
  plt.figure(figsize=(10, 6))
  plt.title(i)
  sns.histplot(df_num[i].to_numpy(), bins=8)
  plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/utils.py:1037: PandasAPIOnSparkAdviceWarning:
#
# `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/utils.py:1037: PandasAPIOnSparkAdviceWarning:
#
# `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/utils.py:1037: PandasAPIOnSparkAdviceWarning:
#
# `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/utils.py:1037: PandasAPIOnSparkAdviceWarning:
#
# `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/utils.py:1037: PandasAPIOnSparkAdviceWarning:
#
# `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/utils.py:1037: PandasAPIOnSparkAdviceWarning:
#
# `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.

# %% [markdown]
# ### Data criação jogos com genero Nan

# %%
p_df=df_final.toPandas()

# %%
p_df["Created"] = pd.to_datetime(p_df["Created"], errors="coerce")

# %%
p_df["Genre"] = p_df["Genre"].replace(
    "N/A",
    np.nan
)

# %%
df_genre_nan = p_df[p_df["Genre"].isna()]

# %%
df_genre_nan.head()
# Out:
#                                 Normalized_name  \
# 2                               pets go 1b luck
# 3                               pets go 1b luck
# 6   scp containment breach part 4 working scp's
# 15                gnomecode's tower defence new
# 18       modded titanic pet simulator z x ps 99
#
#                                                 Title               Creator  \
# 2                              PETS GO! 🍀 [ +1B LUCK]  BK Games Uploading 3
# 3                               PETS GO! 🍀 [+1B LUCK]  BK Games Uploading 3
# 6    SCP Containment Breach - Part 4! (Working SCP...           @joshman901
# 15         [ 😇 ]GnomeCode's Tower Defence  Beta  New!          @noob_YT2823
# 18         [Modded TITANIC] ❄ Pet Simulator Z x PS 99          @buildZgame5
#
#    AgeRecommendation  Active  Favourites    Visits      VoiceChat  \
# 2           All Ages    4281        1521    546300      Supported
# 3           All Ages    1939         685    227800      Supported
# 6           All Ages       6       27872  11600000  Not Supported
# 15          All Ages       0           3       722  Not Supported
# 18          All Ages      30       10507    206100      Supported
#
#            Camera    Created     Updated  ServerSize Genre  Likes  Dislikes  \
# 2       Supported 2024-10-28   11/6/2024          10   NaN   1207        94
# 3       Supported 2024-10-28   11/5/2024          10   NaN    588        42
# 6   Not Supported 2018-05-12  11/10/2022           6   NaN   4409      1207
# 15      Supported 2024-08-03   9/10/2024          25   NaN      6         3
# 18      Supported 2024-09-23   11/6/2024          10   NaN    109        66
#
#                                              GameLink      DateFetched
# 2   https://www.roblox.com/games/89998149942357/PE...  11/6/2024 22:35
# 3   https://www.roblox.com/games/89998149942357/PE...  11/5/2024 21:17
# 6   https://www.roblox.com/games/1754152319/SCP-Co...  11/5/2024 21:37
# 15  https://www.roblox.com/games/18778322468/Gnome...  11/5/2024 21:13
# 18  https://www.roblox.com/games/79780711010428/Mo...  11/6/2024 22:24

# %%
df_genre_nan["Created"].describe()
# Out:
# count                              487
# mean     2023-10-01 19:36:50.266940416
# min                2010-06-14 00:00:00
# 25%                2023-06-25 00:00:00
# 50%                2024-06-29 00:00:00
# 75%                2024-09-29 00:00:00
# max                2024-11-03 00:00:00
# Name: Created, dtype: object

# %%
com_genero = p_df[p_df["Genre"].notna()]
com_genero["Created"].describe()
# Out:
# count                             1047
# mean     2022-02-05 00:15:07.736389632
# min                2008-03-29 00:00:00
# 25%                2021-01-28 00:00:00
# 50%                2022-11-19 00:00:00
# 75%                2023-12-17 12:00:00
# max                2024-09-20 00:00:00
# Name: Created, dtype: object

# %%
sem_genero = p_df[p_df["Genre"].isna()]
com_genero = p_df[p_df["Genre"].notna()]

print("Jogos sem gênero:")
print("Quantidade:", len(sem_genero))
print("Data mínima:", sem_genero["Created"].min())
print("Data média:", sem_genero["Created"].mean())
print("Data mediana:", sem_genero["Created"].median())
print("Data máxima:", sem_genero["Created"].max())

print("\nJogos com gênero:")
print("Quantidade:", len(com_genero))
print("Data mínima:", com_genero["Created"].min())
print("Data média:", com_genero["Created"].mean())
print("Data mediana:", com_genero["Created"].median())
print("Data máxima:", com_genero["Created"].max())
# Out:
# Jogos sem gênero:
# Quantidade: 487
# Data mínima: 2010-06-14 00:00:00
# Data média: 2023-10-01 19:36:50.266940416
# Data mediana: 2024-06-29 00:00:00
# Data máxima: 2024-11-03 00:00:00
#
# Jogos com gênero:
# Quantidade: 1047
# Data mínima: 2008-03-29 00:00:00
# Data média: 2022-02-05 00:15:07.736389632
# Data mediana: 2022-11-19 00:00:00
# Data máxima: 2024-09-20 00:00:00

# %% [markdown]
# ### Avaliação por genero

# %%
genres=p_df["Genre"].unique()

# %%
p_df_plot = p_df.copy()
p_df_plot = p_df_plot[p_df_plot["Genre"].notna()]

# %%
genres = sorted(p_df_plot["Genre"].dropna().unique())

cmap = plt.get_cmap("tab20")

genre_colors = {
    genre: cmap(i / max(len(genres) - 1, 1))
    for i, genre in enumerate(genres)
}

# %%
for col in num_cols:
    medias = (
        p_df_plot
        .groupby("Genre")[col]
        .mean()
        .sort_values(ascending=False)
    )

    colors = [genre_colors[genre] for genre in medias.index]

    plt.figure(figsize=(12, 5))
    medias.plot(kind="bar", color=colors)

    plt.title(f"Média de {col} por gênero")
    plt.xlabel("Gênero")
    plt.ylabel(f"Média de {col}")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %%
for col in num_cols:
    data = []
    labels = []

    for genre in genres:
        values = p_df_plot.loc[p_df_plot["Genre"] == genre, col].dropna()
        if len(values) > 0:
            data.append(values)
            labels.append(genre)

    plt.figure(figsize=(12, 5))

    box = plt.boxplot(
        data,
        tick_labels=labels,
        patch_artist=True
    )

    for patch, genre in zip(box["boxes"], labels):
        patch.set_facecolor(genre_colors[genre])

    plt.title(f"Distribuição de {col} por gênero")
    plt.xlabel("Gênero")
    plt.ylabel(col)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # PCA

# %% [markdown]
# ### Transformando amostras

# %%
from pyspark.sql.functions import log1p, col

df_pca = df_final

cols_log = ["Active", "Visits", "Favourites", "Likes", "Dislikes"]
cols_sem_log = ["ServerSize"]

# Criar versões em log das colunas de contagem
for c in cols_log:
    df_pca = df_pca.withColumn(f"log_{c}", log1p(col(c).cast("double")))

# Converter ServerSize para double
df_pca = df_pca.withColumn("ServerSize", col("ServerSize").cast("double"))

# %%
features_cols = [f"log_{c}" for c in cols_log] + cols_sem_log

assembler = VectorAssembler(
    inputCols=features_cols,
    outputCol="features_raw",
    handleInvalid="skip"
)

df_vector = assembler.transform(df_pca)

# %%
scaler = StandardScaler(
    inputCol="features_raw",
    outputCol="features_scaled",
    withMean=True,
    withStd=True
)

scaler_model = scaler.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

# %% [markdown]
# ### Aplicação PCA

# %%
pca = PCA(
    k=3,
    inputCol="features_scaled",
    outputCol="pca_features"
)

pca_model = pca.fit(df_scaled)
df_pca_result = pca_model.transform(df_scaled)

# %%
pca_model.explainedVariance
# Out:
# DenseVector([0.764, 0.162, 0.0429])

# %%
pc_matrix = pca_model.pc.toArray()

loadings = pd.DataFrame(
    pc_matrix,
    index=features_cols,
    columns=[f"PC{i+1}" for i in range(pc_matrix.shape[1])]
)

loadings
# Out:
#                      PC1       PC2       PC3
# log_Active     -0.414934  0.022038  0.902571
# log_Visits     -0.455157 -0.056848 -0.165338
# log_Favourites -0.447658 -0.040177 -0.143003
# log_Likes      -0.454567 -0.061713 -0.199748
# log_Dislikes   -0.452616 -0.066839 -0.305001
# ServerSize      0.093661 -0.993173  0.068214

# %%
# Separar o vetor pca_features em duas colunas: PC1 e PC2
get_pc1 = udf(lambda v: float(v[0]), DoubleType())
get_pc2 = udf(lambda v: float(v[1]), DoubleType())

df_pca_plot = (
    df_pca_result
    .withColumn("PC1", get_pc1(col("pca_features")))
    .withColumn("PC2", get_pc2(col("pca_features")))
    .select("Title", "Genre", "PC1", "PC2")
)

pdf_pca = df_pca_plot.toPandas()

# %%
fig = px.scatter(
    pdf_pca,
    x="PC1",
    y="PC2",
    color="Genre",
    hover_name="Title",
    hover_data={
        "Genre": True,
        "PC1": ":.2f",
        "PC2": ":.2f"
    },
    title="PCA dos jogos do Roblox por gênero"
)

fig.update_layout(
    xaxis_title="PC1",
    yaxis_title="PC2",
    legend_title="Gênero"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e14ac9e5-6654-410c-bda5-ede5b3d98ec2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e14ac9e5-6654-410c-bda5-ede5b3d98ec2")) {                    Plotly.newPlot(                        "e14ac9e5-6654-410c-bda5-ede5b3d98ec2",                        [{"customdata":[["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],["Simulation"],[ ...

# %%
plot_pca_spark = (
    df_pca_result
    .withColumn("PC1", get_pc1(col("pca_features")))
    .withColumn("PC2", get_pc2(col("pca_features")))
    .select("Title", "Genre","Active","Visits","Favourites","Likes","Dislikes","ServerSize","PC1","PC2")
)

plot_pca = plot_pca_spark.toPandas()

fig = px.scatter(
    plot_pca,
    x="PC1",
    y="PC2",
    color="Genre",
    hover_name="Title",
    hover_data={
        "Genre": True,
        "Active": True,
        "Visits": True,
        "Favourites": True,
        "Likes": True,
        "Dislikes": True,
        "ServerSize": True,
        "PC1": ":.2f",
        "PC2": ":.2f"
    },
    title="PCA dos jogos do Roblox por gênero"
)

fig.update_layout(
    xaxis_title="PC1",
    yaxis_title="PC2",
    legend_title="Gênero"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="46958735-c1a2-4048-883d-a9656e806657" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46958735-c1a2-4048-883d-a9656e806657")) {                    Plotly.newPlot(                        "46958735-c1a2-4048-883d-a9656e806657",                        [{"customdata":[["Simulation",206,79300000,191886,285000,12000,12.0],["Simulation",1006,32066588,55544,46677,3736,8.0],["Simulation",81975,778100000,640825,755000,101000,20.0],["Simulation",24826,760264927,633329,742478,100411,20.0],["Simulation",80,3400000,1542,244,101,50.0],["Simulation",93,3400000,1571,245,104,50.0],["Simulation",0,1900000,121699,29000,2939,8.0],["Simulation",229,72800000,418927,76000,13000,20.0],["Simulation",172,1300000,4865,1527,385,1.0],["Simulation",3283,444200000,1748547,798000,28000,1.0],["Simulation",1351,209972653,274532,87708,19444,1.0],["Simulation",481,67600000,252867,57000,10000,25.0],["Simulation",708,84186547,85250,86006,6117,7.0],["Simulation",903,232334343,7395147,384880,20038,12.0],["Simulation",1131,283820606,785618,226415,24410,9.0],["Simulation",113,4700000,14239,3017,1812,20.0],["Simulation",540,65500000,119021,98000,9216,12.0],["Simulation",728,145062000,204447,170000,9460,10.0],["Simulation",384,105800000,159418,81000,8091,18.0],["Simulation",445,32500000,49356,98000,2905,12.0],["Simulation",12203,1034041412,896464,1152803,58366,9.0],["Simulation",4312,213400000,484024,132000,18000,50.0],["Simulation",196,29600000,182840,48000,10000,5.0],["Simulation",193,1200000,4573,1419,363,1.0],["Simulation",184,1400000,4922,1543,399,1.0],["Simulation",741,63398806,4197056,136660,10151,15.0],["Simulation",104,6400000,49937,8984,2662,6.0],["Simulation",317,5100000,21212,61000,1052,20.0],["Simulation",425,5300000,21870,63000,1088,20.0],["Simulation",16,17300000,49982,15000,3643,12.0],["Simulation",762,17823916,989708,92172,11564,8.0],["Simulation",1137,53413255,109973,99091,13343,12.0],["Simulation",1655,52638702,73819,80244,10182,10.0],["Simulation",2514,34027969,1228618,105542,10058,16.0],["Simulation",157,27900000,271717,140000,9477,30.0],["Simulation",31885,2983678381,5954749,2317866,123885,6.0],["Simulation",1073,416642513,850340,209490,18124,6.0],["Simulation",907,132300000,326524,132000,13000,15.0],["Simulation",773,8600000,538860,39000,776,8.0],["Simulation",875,85630922,247568,82803,19620,4.0],["Simulation",44,10400000,16786,7086,872,15.0],["Simulation",474,5400000,298032,204,176,12.0],["Simulation",975,5583581,32716,24507,2021,6.0],["Simulation",430,66500000,54502,111000,2556,12.0],["Simulation",2093,9303022,1128067,1018,1536,8.0],["Simulation",1182,1409645,6662,1333,293,11.0],["Simulation",4161,1229170357,4161887,1309796,174621,30.0],["Simulation",11,447800,60924,7332,609,6.0],["Simulation",23803,4091953952,7634669,3053389,227152,7.0],["Simulation",193,59100000,182224,38000,17000,8.0],["Simulation",6915,27359902,1284646,96024,2808,9.0],["Simulation",6915,27359902,1284646,96024,2808,9.0],["Simulation",965,96667217,173005,333321,12694,20.0],["Simulation",1492,413201523,2522531,244510,33021,10.0],["Simulation",1093,18800000,25452,6778,2322,15.0],["Simulation",2759,40675299,39855,7355,4680,8.0],["Simulation",1141,11040799,735951,64760,2371,8.0],["Simulation",1180,49748616,4908321,8989,2770,12.0],["Simulation",2999,218367183,2890209,53222,8395,10.0],["Simulation",1136,75341370,6111509,51028,4059,4.0],["Simulation",740,1063747,10760,10611,821,35.0],["Simulation",21,639700,2335,4347,591,40.0],["Simulation",749,17843797,44887,154198,2202,10.0],["Simulation",1011,2743732,385167,1348,111,5.0],["Simulation",766,179895607,271501,57241,36104,7.0],["Simulation",4216,157797182,277644,108854,8460,12.0],["Simulation",2298,547662230,1596634,448746,10006 ...

# %% [markdown]
# # Clustering

# %% [markdown]
# ## K-Means

# %%
kmeans = KMeans(
    k=3,
    seed=42,
    featuresCol="features_scaled",
    predictionCol="cluster_kmeans"
)

kmeans_model = kmeans.fit(df_scaled)

df_cluster = kmeans_model.transform(df_scaled)

# %%
evaluator = ClusteringEvaluator(
    featuresCol="features_scaled",
    predictionCol="cluster_kmeans",
    metricName="silhouette",
    distanceMeasure="squaredEuclidean"
)

silhouette = evaluator.evaluate(df_cluster)

# %%
resultados_k = []

for k in range(2, 9):
    kmeans = KMeans(
        k=k,
        seed=42,
        featuresCol="features_scaled",
        predictionCol="cluster_kmeans"
    )

    model = kmeans.fit(df_scaled)
    predictions = model.transform(df_scaled)
    silhouette = evaluator.evaluate(predictions)

    resultados_k.append((k, silhouette))
    print(f"k={k} | silhouette={silhouette:.4f}")
# Out:
# k=2 | silhouette=0.7128
# k=3 | silhouette=0.7247
# k=4 | silhouette=0.4381
# k=5 | silhouette=0.5587
# k=6 | silhouette=0.4711
# k=7 | silhouette=0.4260
# k=8 | silhouette=0.3519

# %%
df_cluster_pca = (
    kmeans_model.transform(df_pca_result)
    .withColumn("PC1", get_pc1(col("pca_features")))
    .withColumn("PC2", get_pc2(col("pca_features")))
    .select(
        "Title",
        "Genre",
        "PC1",
        "PC2",
        "cluster_kmeans",
        "Active",
        "Visits",
        "Likes",
        "Dislikes",
        "Favourites",
        "ServerSize"
    )
)

# %%
pdf_cluster_pca = df_cluster_pca.toPandas()

# %%
pdf_cluster_pca["cluster_kmeans"] = pdf_cluster_pca["cluster_kmeans"].astype(str)

fig = px.scatter(
    pdf_cluster_pca,
    x="PC1",
    y="PC2",
    color="cluster_kmeans",
    hover_name="Title",
    hover_data={
        "Genre": True,
        "Active": True,
        "Visits": True,
        "Likes": True,
        "Dislikes": True,
        "Favourites": True,
        "ServerSize": True,
        "PC1": ":.2f",
        "PC2": ":.2f"
    },
    title="Clusters dos jogos do Roblox visualizados no PCA"
)

fig.update_layout(
    xaxis_title="PC1",
    yaxis_title="PC2",
    legend_title="Cluster"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7a0833b9-2958-41f2-993f-e516149d465d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a0833b9-2958-41f2-993f-e516149d465d")) {                    Plotly.newPlot(                        "7a0833b9-2958-41f2-993f-e516149d465d",                        [{"customdata":[["Simulation",206,79300000,285000,12000,191886,12.0],["Simulation",1006,32066588,46677,3736,55544,8.0],["Survival",27466,13110395425,3615821,406011,11669525,6.0],["N\u002fA",6,11600000,4409,1207,27872,6.0],["Simulation",81975,778100000,755000,101000,640825,20.0],["Simulation",24826,760264927,742478,100411,633329,20.0],["Survival",7446,40646073,33850,4351,69118,8.0],["Survival",7446,40646073,33850,4351,69118,8.0],["Adventure",87,6500000,4550,770,51231,25.0],["Social",6859,153200000,74000,6912,232111,30.0],["Social",2373,151700000,73000,6868,230494,30.0],["Survival",12843,982471025,979569,107362,2901837,45.0],["Simulation",0,1900000,29000,2939,121699,8.0],["Simulation",229,72800000,76000,13000,418927,20.0],["Roleplay & Avatar Sim",215,11800000,15000,2357,14206,50.0],["N\u002fA",34,3300000,4126,885,15646,1.0],["Simulation",3283,444200000,798000,28000,1748547,1.0],["Adventure",1055,39846487,115256,10176,497291,60.0],["N\u002fA",19,3200000,4058,869,15240,1.0],["Sports & Racing",1099,59813777,64497,7600,199956,10.0],["Simulation",1351,209972653,87708,19444,274532,1.0],["Action",29729,459400000,103000,39000,5589050,22.0],["Simulation",481,67600000,57000,10000,252867,25.0],["N\u002fA",5082,1100000,3306,100,71838,50.0],["Simulation",708,84186547,86006,6117,85250,7.0],["Simulation",903,232334343,384880,20038,7395147,12.0],["Obby & Platformer",756,186781037,44142,21490,7110792,65.0],["Obby & Platformer",634,39100000,27000,5382,123622,22.0],["Simulation",1131,283820606,226415,24410,785618,9.0],["Survival",1146,75753565,19578,6971,76824,100.0],["Survival",16218,2356878957,1648983,152249,4831147,16.0],["N\u002fA",819,78768613,19767,7247,81002,10.0],["Action",773,132392495,39453,15420,130083,10.0],["Action",762,26308244,4490,2286,17567,10.0],["Action",1613,409410638,356837,97884,653578,18.0],["Roleplay & Avatar Sim",109439,37679655130,7323639,1441230,26994071,48.0],["N\u002fA",569,18700000,46000,8273,390076,48.0],["Simulation",113,4700000,3017,1812,14239,20.0],["Shooter",787,10803256,13500,3900,228469,16.0],["Shooter",1172,212613532,44047,14220,140534,8.0],["Obby & Platformer",1104,259009254,174791,23350,988309,24.0],["Simulation",540,65500000,98000,9216,119021,12.0],["Roleplay & Avatar Sim",1153,159969846,27313,5280,152746,35.0],["Party & Casual",1161,103223429,23595,4885,69455,18.0],["Simulation",728,145062000,170000,9460,204447,10.0],["Simulation",384,105800000,81000,8091,159418,18.0],["Survival",2129,225905982,158439,40572,4000296,8.0],["Adventure",2230,320260781,496789,39610,1782323,100.0],["Action",2378,101273864,199556,27150,735946,30.0],["Simulation",445,32500000,98000,2905,49356,12.0],["Simulation",12203,1034041412,1152803,58366,896464,9.0],["Shooter",6473,5601255572,4904838,622547,11172088,16.0],["Shopping",1009,200921111,31581,8186,151499,16.0],["Shopping",808,97527799,6015,2339,46370,27.0],["Simulation",4312,213400000,132000,18000,484024,50.0],["Obby & Platformer",257,4400000,1152,473,28614,24.0],["N\u002fA",364,4300000,2663,185,493617,50.0],["Obby & Platformer",1455,48949621,19639,18254,47792,50.0],["Simulation",196,29600000,48000,10000,182840,5.0],["Adventure",105,35600000,33000,19000,436248,30.0],["Social",74,843900,8368,984,40406,50.0],["Shooter",448,18300000,3301,2132,11790,12.0],["Survival",346,59000000,24000,5669,163946,16.0],["Action",6518,445900000,101000,38000,5573515,22.0],["Survival",128,26600000,10000,3445,42355,100.0],["Simulation",741,63398806,136 ...

# %% [markdown]
# ## C-Fuzzy

# %% [markdown]
# ### Código

# %%
def generate_random_relevence(X,k,seed=10):

    '''
    Atribui a cada item uma relevância aleatória para cada grupo k.
    Garante que a soma de cada linha seja 1.
    '''

    np.random.seed(seed)
    relevences=[]

    for i in range(len(X)):
        relevences.append([])
        aux=0
        sum=0

        for j in range(k):
            relevences[i].append(np.random.uniform(0,1-aux))
            aux+=relevences[i][j]
            sum+=relevences[i][j]

        if sum!=1:
            relevences[i][0]=1-sum+relevences[i][0]

    return np.array(relevences)


def pertinencias(X, C, m):
    '''
    X: matriz de amostras
    C: matriz de centróides
    m: parâmetro de fuzziness

    Calcula a pertinência w_ij de xi ao centróide C[j]
    usando cdist para calcular as distâncias euclidianas.
    '''

    # cdist é de matrizes 2D, então fiz o reshape xi para (1, n_features)
    # ai da um o array do shape com a distancia de xi pro centroide

    U=[]

    distancias = cdist(X, C, metric='euclidean')

    exponent = 2 / (m - 1)

    for i in distancias:
        aux_U=[]

        for dist_j in i:
            sum = 0

            for dist_l in i:

                if dist_l == 0:
                    sum+=(1.0 if dist_l == dist_j else 0.0)
                else:
                    sum += (dist_j / dist_l)**exponent

            aux_U.append(1 / sum)

        U.append(aux_U)

    return np.array(U)


def centroid_update(X, U, m):

    k = U.shape[1]
    C = []

    for j in range(k):
        numerador = 0
        denominador = 0

        for i in range(len(X)):
            numerador += (U[i][j]) * X[i]
            denominador += U[i][j]

        C.append(numerador/denominador)

    return np.array(C)


def objective_function(X,C,U):

    '''
    X: matriz de dados
    C: matriz de centróides
    U: matriz de pertinência
    Calcula a função objetivo do FCM
    '''

    n_samples = X.shape[0]
    n_clusters = C.shape[0]
    J = 0

    for i in range(n_samples):
        for j in range(n_clusters):
            u_ij = U[i, j]
            J += (u_ij) * (np.linalg.norm(X[i] - C[j]) ** 2)

    return J

# %%
def fuzzy_cmeans(X, k, m, max_iter=100, conv = 0.001):

    n_samples = X.shape[0] #n° de linhas

    J_history = []

    U = generate_random_relevence(X, k) #cria a matriz de pertinência aleatória inicial

    C=centroid_update(X, U, m) #inicializa a matriz de centróides

    for iteration in range(max_iter):
        C_old = C.copy()

        U=pertinencias(X, C, m)
        C = centroid_update(X, U, m)
        J = objective_function(X, C, U)


        J_history.append(J)
        convergence = np.linalg.norm(C - C_old)

        if convergence < conv:
            print(f"Convergiu na iteração {iteration}")
            break

        labels = np.argmax(U, axis=1)


    return U, C, labels, J_history

# %% [markdown]
# ### Aplicando

# %%
p_df_fcm = df_scaled.select(
    "Title",
    "Genre",
    "features_scaled"
).toPandas()

# %%
X_fcm = np.vstack(
    p_df_fcm["features_scaled"].apply(lambda v: v.toArray())
)

# %%
U, C, labels, J_history = fuzzy_cmeans(X_fcm,k=3,m=2,)
# Out:
# Convergiu na iteração 55

# %%
p_df_fcm["cluster_fuzzy"] = labels
p_df_fcm["max_pertinencia"] = U.max(axis=1)

for i in range(U.shape[1]):
    p_df_fcm[f"pertinencia_cluster_{i}"] = U[:, i]

# %%
pdf_fcm_plot = pdf_pca.merge(
    p_df_fcm.drop(columns=["Genre"], errors="ignore"),
    on="Title",
    how="inner"
)

# %%
pdf_fcm_plot["cluster_fuzzy"] = pdf_fcm_plot["cluster_fuzzy"].astype(str)

fig = px.scatter(
    pdf_fcm_plot,
    x="PC1",
    y="PC2",
    color="cluster_fuzzy",
    size="max_pertinencia",
    hover_name="Title",
    hover_data={
        "Genre": True,
        "max_pertinencia": ":.3f",
        "pertinencia_cluster_0": ":.3f",
        "pertinencia_cluster_1": ":.3f",
        "pertinencia_cluster_2": ":.3f",
        "PC1": ":.2f",
        "PC2": ":.2f"
    },
    title="Fuzzy C-Means visualizado no espaço PCA"
)

fig.update_layout(
    xaxis_title="PC1",
    yaxis_title="PC2",
    legend_title="Cluster Fuzzy"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ba13dcc-b5e4-40ee-b7cb-de6681619eee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ba13dcc-b5e4-40ee-b7cb-de6681619eee")) {                    Plotly.newPlot(                        "6ba13dcc-b5e4-40ee-b7cb-de6681619eee",                        [{"customdata":[["Simulation",0.6211104757319137,0.04727261099372395,0.3316169132743624,0.6211104757319137],["Survival",0.5215804178306341,0.1299237224377815,0.3484958597315844,0.5215804178306341],["Simulation",0.5524964153957151,0.10489750639509124,0.3426060782091936,0.5524964153957151],["Simulation",0.5837708526160978,0.08907977146300561,0.3271493759208965,0.5837708526160978],["Survival",0.5411949918918381,0.0578340334500361,0.400970974658126,0.5411949918918381],["Survival",0.5411949918918381,0.0578340334500361,0.400970974658126,0.5411949918918381],["Social",0.6799223705465484,0.03845559740036977,0.28162203205308184,0.6799223705465484],["Social",0.7874283837620933,0.018921475943791427,0.19365014029411518,0.7874283837620933],["Survival",0.565983139945631,0.09897431730463117,0.3350425427497379,0.565983139945631],["Simulation",0.6958256620785138,0.027317409155055317,0.2768569287664308,0.6958256620785138],["Simulation",0.6087389570710948,0.07549427506909501,0.3157667678598101,0.6087389570710948],["Adventure",0.529547830250061,0.0832187979921475,0.3872333717577915,0.529547830250061],["Sports & Racing",0.7437595081185893,0.019566838930608257,0.23667365295080245,0.7437595081185893],["Simulation",0.6582665814348233,0.04700200337435788,0.2947314151908188,0.6582665814348233],["Action",0.5832146564028705,0.08628528346758689,0.33050006012954264,0.5832146564028705],["Simulation",0.872468228837532,0.00729094150695234,0.12024082965551583,0.872468228837532],["Simulation",0.6243202266251696,0.03337585719394732,0.342303916180883,0.6243202266251696],["Simulation",0.6289256771478947,0.06565687374751657,0.30541744910458885,0.6289256771478947],["Obby & Platformer",0.5153300785189593,0.1104618280077755,0.37420809347326517,0.5153300785189593],["Obby & Platformer",0.546011591496902,0.008660483768085172,0.4453279247350127,0.546011591496902],["Simulation",0.692591821458337,0.04460890279290007,0.262799275748763,0.692591821458337],["Survival",0.5617885283777614,0.10364210501911272,0.3345693666031259,0.5617885283777614],["N\u002fA",0.5634225536133256,0.028513588163893745,0.40806385822278074,0.5634225536133256],["Action",0.7085326484818301,0.026258110521113973,0.2652092409970559,0.7085326484818301],["Action",0.6592836097409139,0.05806916026065723,0.28264722999842884,0.6592836097409139],["Roleplay & Avatar Sim",0.4882667966735104,0.15539894246066302,0.35633426086582654,0.4882667966735104],["N\u002fA",0.5216076939159131,0.05436735335042884,0.4240249527336582,0.5216076939159131],["Shooter",0.6969350792167127,0.03193320708912248,0.2711317136941648,0.6969350792167127],["Obby & Platformer",0.7450424722034438,0.03316176503045838,0.22179576276609783,0.7450424722034438],["Simulation",0.7086115765823305,0.022490567645792003,0.2688978557718774,0.7086115765823305],["Roleplay & Avatar Sim",0.665044385396025,0.02361283931783239,0.3113427752861426,0.665044385396025],["Party & Casual",0.6024476321962522,0.0197848413150156,0.3777675264887323,0.6024476321962522],["Simulation",0.7215780097057781,0.029517135341101692,0.24890485495312023,0.7215780097057781],["Simulation",0.7479373847440869,0.017639202329838278,0.2344234129260748,0.7479373847440869],["Survival",0.6430118644687177,0.061273147690879215,0.2957149878404031,0.6430118644687177],["Adventure",0.45337179704973846,0.1708696717528949,0.37575853119736663,0.45337179704973846],["Action",0.7354418608743711,0.03440351873529844,0.2301546203903305,0.7354418608743711],["Simula ...

# %% [markdown]
# # Avaliação retirando N/a e outliers

# %% [markdown]
# ## Criar df

# %%
df_no_nan=df_final

# %%
numeric_cols_spark = ["Active", "Favourites", "Visits", "Likes", "Dislikes", "ServerSize"]
text_cols_spark    = ["Genre", "Title", "Creator", "AgeRecommendation",
                      "VoiceChat", "Camera", "Created", "Updated"]

# 1- Remove linhas com null/NaN nas colunas numéricas
for c in numeric_cols_spark:
    df_no_nan = df_no_nan.filter(col(c).isNotNull())

# 2- Remove linhas com null, string vazia ou N/A nas colunas de texto
for c in text_cols_spark:
    df_no_nan = df_no_nan.filter(
        col(c).isNotNull() &
        (trim(col(c)) != "") &
        (trim(col(c)) != "N/A")
    )

print(f"Linhas após remoção de NaN (todas as colunas): {df_no_nan.count()}")

# 3- Remove outliers via IQR nas colunas numéricas
for c in numeric_cols_spark:
    quantiles = df_no_nan.select(
        percentile_approx(col(c), 0.25).alias("q1"),
        percentile_approx(col(c), 0.75).alias("q3")
    ).collect()[0]

    q1  = quantiles["q1"]
    q3  = quantiles["q3"]
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    print(f"{c}: Q1={q1}, Q3={q3}, IQR={iqr}, limites=[{lower_bound:.2f}, {upper_bound:.2f}]")

    df_no_nan = df_no_nan.filter(
        (col(c) >= lower_bound) & (col(c) <= upper_bound)
    )

print(f"\nLinhas após remoção de outliers: {df_no_nan.count()}")
df_no_nan.show(5)
# Out:
# Linhas após remoção de NaN (todas as colunas): 636
# Active: Q1=194, Q3=1186, IQR=992, limites=[-1294.00, 2674.00]
# Favourites: Q1=32716, Q3=280790, IQR=248074, limites=[-339395.00, 652901.00]
# Visits: Q1=8258812, Q3=68666787, IQR=60407975, limites=[-82353150.50, 159278749.50]
# Likes: Q1=6706, Q3=54000, IQR=47294, limites=[-64235.00, 124941.00]
# Dislikes: Q1=1163, Q3=7598, IQR=6435, limites=[-8489.50, 17250.50]
# ServerSize: Q1=10, Q3=30, IQR=20, limites=[-20.00, 60.00]
#
# Linhas após remoção de outliers: 431
# +--------------------+--------------------+--------------------+-----------------+------+----------+---------+-------------+-------------+---------+----------+----------+-------------+-----+--------+--------------------+----------------+
# |     Normalized_name|               Title|             Creator|AgeRecommendation|Active|Favourites|   Visits|    VoiceChat|       Camera|  Created|   Updated|ServerSize|        Genre|Likes|Dislikes|            GameLink|     DateFetched|
# +--------------------+--------------------+--------------------+-----------------+------+----------+---------+-------------+-------------+---------+----------+----------+-------------+-----+--------+--------------------+----------------+
# |   gun armory tycoon|   Gun Armory Tycoon|       Raven Network|          Ages 9+|  1006|     55544| 32066588|Not Supported|    Supported|4/25/2024|10/17/2024|         8|   Simulation|46677|    3736|https://www.roblo...| 11/6/2024 22:47|
# |  roblox spirit 2024| Roblox Spirit Ha...|         @JohnTRoblo|         All Ages|    13|       731|   417900|Not Supported|Not Supported|4/20/2024| 9/18/2024|        50|Entertainment|  348|      98|https://www.roblo...| 11/9/2024 23:57|
# |sonic evocative r...| Sonic Evocative:...|Tails Team Roblox...|         All Ages|    80|      1542|  3400000|Not Supported|Not Supported|6/29/2024| 11/9/2024|        50|   Simulation|  244|     101|https://www.roblo...|11/11/2024 11:29|
# |          strict mom|        Strict Mom👿|      Creepy Studio.|         All Ages|    87|     51231|  6500000|Not Supported|Not Supported| 1/3/2024|11/11/2024|        25|    Adventure| 4550|     770|https://www.roblo...| 11/13/2024 9:26|
# |         diva 15 tod| [ DIVA + 15] TOD 🎃|     OofMayy Studios|         All Ages|  2373|    230494|151700000|    Supported|    Supported|1/25/2023| 11/4/2024|        30|       Social|73000|    6868|https://www.roblo...| 11/5/2024 20:29|
# +--------------------+--------------------+--------------------+-----------------+------+----------+---------+-------------+-------------+---------+----------+----------+-------------+-----+--------+--------------------+----------------+
# only showing top 5 rows

# %%
numeric_cols_plot = ["Active", "Favourites", "Visits", "Likes", "Dislikes", "ServerSize"]

data_dict = {}
for c in numeric_cols_plot:
    data_dict[c] = [row[c] for row in df_no_nan.select(c).collect()]

genres_raw  = [row["Genre"] for row in df_no_nan.select("Genre").collect()]

# %%
# 1- BOX PLOTS

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle("Box Plots – Dados sem NaN e sem Outliers", fontsize=16, fontweight="bold")

for ax, col_name in zip(axes.flatten(), numeric_cols_plot):
    ax.boxplot(data_dict[col_name], patch_artist=True,
               boxprops=dict(facecolor="#4C9BE8", color="#1a1a2e"),
               medianprops=dict(color="#FF6B6B", linewidth=2),
               whiskerprops=dict(color="#1a1a2e"),
               capprops=dict(color="#1a1a2e"),
               flierprops=dict(marker="o", color="#FF6B6B", markersize=3, alpha=0.5))
    ax.set_title(col_name, fontsize=13)
    ax.set_ylabel("Valor")
    ax.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# 2- SCATTER PLOTS

genres_uniq = list(set(genres_raw))
palette     = dict(zip(genres_uniq, sns.color_palette("tab10", len(genres_uniq))))
colors      = [palette[g] for g in genres_raw]

scatter_pairs = [
    ("Visits",     "Active",     "Visitas vs Jogadores Ativos"),
    ("Visits",     "Likes",      "Visitas vs Likes"),
    ("Likes",      "Dislikes",   "Likes vs Dislikes"),
    ("Favourites", "Active",     "Favoritos vs Jogadores Ativos"),
    ("ServerSize", "Active",     "Tamanho do Servidor vs Jogadores Ativos"),
    ("Favourites", "Likes",      "Favoritos vs Likes"),
]

fig, axes = plt.subplots(2, 3, figsize=(18, 11))
fig.suptitle("Scatter Plots – Dados sem NaN e sem Outliers", fontsize=16, fontweight="bold")

for ax, (x_col, y_col, title) in zip(axes.flatten(), scatter_pairs):
    ax.scatter(data_dict[x_col], data_dict[y_col],
               c=colors, alpha=0.6, edgecolors="none", s=30)
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title(title, fontsize=11)
    ax.grid(linestyle="--", alpha=0.4)

handles = [plt.Line2D([0], [0], marker="o", color="w",
           markerfacecolor=palette[g], markersize=8, label=g)
           for g in genres_uniq]
fig.legend(handles=handles, title="Genre", loc="lower center",
           ncol=min(len(genres_uniq), 6), bbox_to_anchor=(0.5, -0.03),
           fontsize=9, title_fontsize=10)

plt.tight_layout()
plt.subplots_adjust(bottom=0.12)
plt.show()

# %%
# 3- SCATTER INTERATIVO (Plotly)

rows = df_no_nan.select("Visits", "Likes", "Active", "Genre",
                         "Dislikes", "Favourites", "ServerSize").collect()

fig_px = px.scatter(
    x=[r["Visits"]  for r in rows],
    y=[r["Likes"]   for r in rows],
    color=[r["Genre"]  for r in rows],
    size=[max(r["Active"], 1) for r in rows],  # evita size=0 que dá erro
    hover_data={
        "Dislikes":   [r["Dislikes"]   for r in rows],
        "Favourites": [r["Favourites"] for r in rows],
        "ServerSize": [r["ServerSize"] for r in rows],
    },
    labels={"x": "Visits", "y": "Likes", "color": "Genre", "size": "Active"},
    title="Visitas vs Likes por Gênero (tamanho = Jogadores Ativos)",
    opacity=0.7,
    template="plotly_white"
)
fig_px.update_layout(legend_title_text="Gênero")
fig_px.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="64e9e705-3f0d-4adf-900a-a9e4edadfa6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64e9e705-3f0d-4adf-900a-a9e4edadfa6b")) {                    Plotly.newPlot(                        "64e9e705-3f0d-4adf-900a-a9e4edadfa6b",                        [{"customdata":[[3736,55544,8],[101,1542,50],[104,1571,50],[2939,121699,8],[13000,418927,20],[385,4865,1],[10000,252867,25],[6117,85250,7],[1812,14239,20],[9216,119021,12],[8091,159418,18],[2905,49356,12],[10000,182840,5],[363,4573,1],[399,4922,1],[2662,49937,6],[1052,21212,20],[1088,21870,20],[3643,49982,12],[13343,109973,12],[10182,73819,10],[776,538860,8],[872,16786,15],[176,298032,12],[2021,32716,6],[2556,54502,12],[293,6662,11],[609,60924,6],[17000,182224,8],[2322,25452,15],[821,10760,35],[591,2335,40],[111,385167,5],[1444,33186,8],[1090,29970,8],[9064,140292,15],[15000,350183,15],[1631,20267,12],[5608,249990,4],[1112,16667,21],[2261,329536,35],[4912,309123,12],[1051,13335,10],[9142,92478,20],[5191,155879,6],[3774,30141,20],[2682,41843,7],[8401,82625,20],[2749,20085,20],[2744,20045,20],[7440,446732,6],[1634,13545,50],[5986,82392,8],[1874,43095,25],[7217,441488,10],[4438,102670,40],[3208,46637,12],[4121,57152,12],[1663,84084,20],[165,9892,10],[1457,25648,1],[627,206622,24],[1428,8270,9],[4054,75576,6],[920,11089,16],[1766,38000,12],[1005,67530,8],[2150,7062,6],[245,3528,5],[8940,57611,40],[526,25458,40],[8084,82323,40],[102,317,15],[1510,15893,15],[1244,13481,6],[213,629130,4],[7378,62875,5],[5825,88955,8],[890,28214,1],[1111,13589,1],[1246,7996,6],[13524,167802,8],[4741,122375,6],[1219,14504,5],[478,2223,25],[2426,37138,7],[3930,53507,1],[3165,66351,6],[629,257858,13],[354,2829,16],[1710,26741,16],[2980,73716,4],[766,628909,12],[1973,99420,1],[1312,28294,6],[1228,14257,15],[1952,38397,4],[10715,271474,25],[5825,88955,8],[2443,83311,35],[517,3685,1],[631,13885,12],[1160,67831,6],[1322,114149,15],[4547,51698,20],[274,3813,12],[1864,46360,16],[14000,291151,8],[4484,442329,20],[2012,49889,16],[2900,49066,20],[457,10618,8],[1104,16499,21],[1070,15998,21],[5164,61135,16],[7562,120161,12],[100,2571,12],[4874,83645,15],[94,1431,50],[4929,58893,16],[4899,84031,15],[2167,25413,8],[2167,25413,8],[2982,33714,10],[540,4722,18],[655,6671,25],[5483,111601,15],[932,7430,12],[2225,33199,4],[4771,315019,16],[4798,314968,16],[11000,284095,40],[3177,100428,12],[1231,24910,12],[4811,314954,16],[4907,84170,15],[436,434916,6],[3948,402086,6],[3616,53694,60],[11000,235373,8],[517,5841,8]],"hovertemplate":"Genre=Simulation\u003cbr\u003eVisits=%{x}\u003cbr\u003eLikes=%{y}\u003cbr\u003eActive=%{marker.size}\u003cbr\u003eDislikes=%{customdata[0]}\u003cbr\u003eFavourites=%{customdata[1]}\u003cbr\u003eServerSize=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Simulation","marker":{"color":"#636efa","opacity":0.7,"size":[1006,80,93,1,229,172,481,708,113,540,384,445,196,193,184,104,317,425,16,1137,1655,773,44,474,975,430,1182,11,193,1093,740,21,1011,27,86,737,48,1536,444,297,748,1329,55,634,204,1008,98,228,279,162,1081,190,1626,891,454,746,34,912,2111,26,92,1005,1927,785,834,2491,1580,1061,145,213,15,202,22,75,71,219,293,964,22,89,983,1707,2049,26,32,555,416,134,213,20,1026,1022,97,1206,930,1689,131,916,964,908,19,151,1037,305,183,79,1089,100,350,1024,962,22,478,447,1540,707,99,371,121,2269,412,2552,2552,125,121,188,882,84,731,112,116,43,21,281,113,578,783,1068,241,72,244],"sizemode":"area","sizeref":6.6175,"symbol":"circle"},"mode":"markers","name":"Simulation","orientation":"v","showlegend":true,"x":[32066588,3400000,3400000,1900000,72800000,1300000,67600000,84186547,4700000,65500000,105800000,32500000,29600000,1200000,1400000,6400000,5100000,5300000,17300000,53413255,526387 ...
